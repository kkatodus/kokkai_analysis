# %%
import os
import re
from params.paths import ROOT_DIR
from api_requests.meeting_convo_collector import MeetingConvoCollector
from file_handling.file_read_writer import read_json, write_json, create_dir, write_file
#paths
LOWER_HOUSE_DATA_DIR = os.path.join(ROOT_DIR, 'data', 'data_shugiin')
UPPER_HOUSE_DATA_DIR = os.path.join(ROOT_DIR, 'data', 'data_sangiin')

#reading the reprentative data for lower and upper house
lower_repr_dir = os.path.join(LOWER_HOUSE_DATA_DIR, 'repr_list')
lower_repr_file = os.listdir(lower_repr_dir)[0]
lower_house_member_list = read_json(os.path.join(lower_repr_dir, lower_repr_file))
speech_freq_file_path = os.path.join(LOWER_HOUSE_DATA_DIR, 'speech_freq.json')

upper_repr_dir = os.path.join(UPPER_HOUSE_DATA_DIR, 'repr_list')
upper_repr_file = os.listdir(upper_repr_dir)[0]
upper_house_member_list = read_json(os.path.join(upper_repr_dir, upper_repr_file))
# %%
mcc = MeetingConvoCollector("https://kokkai.ndl.go.jp/api/speech?")

# %%
def clean_repr_name(repr_name):
	repr_name = re.sub('\s|君|\[(.*?)\]', '', repr_name)
	return repr_name
def get_total_speech_freq_from_api(responses):
	freq = 0
	for response in responses:
		freq += response['numberOfRecords']
	return freq

def get_speech_freq_for_repr_for_year(repr_name, start_year):
	conditions_list = [
			f"speaker={repr_name}",
			f"from={start_year}-01-01",
			f"until={start_year}-12-31",
			# f"nameOfHouse=両院",
			'recordPacking=json'
	]
	search_requests = mcc.make_requests(conditions_list=conditions_list)
	return get_total_speech_freq_from_api(search_requests)

# %%
while True:
	try:
		output_arr = []
		if os.path.exists(speech_freq_file_path):
			output_arr = read_json(speech_freq_file_path)
		for idx, year in enumerate(range(1990, 2023)):
			if idx < len(output_arr):
				continue
			year_dict = {
				'year': year,
			}
			for party, members in lower_house_member_list['reprs'].items():
				for member in members:
					name = member['name']
					name = clean_repr_name(name)
					freq = get_speech_freq_for_repr_for_year(name, year)
					year_dict[f'{party} {name}'] = freq
					
			output_arr.append(year_dict)	
			write_json(output_arr, speech_freq_file_path)
	except Exception as e:
		print(e)
		print('Exception occured trying again')
# Out:
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=逢沢一郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=逢沢一郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=青山周平&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=青山周平&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=赤澤亮正&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=赤澤亮正&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=赤澤亮正&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=あかま二郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=あかま二郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=あかま二郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=91&speaker=あかま二郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=121&speaker=あかま二郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=151&speaker=あかま二郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=あかま二郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=秋葉賢也&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=秋葉賢也&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=秋本真利&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=秋本真利&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=秋本真利&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=東国幹&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=東国幹&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=畦元将吾&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=畦元将吾&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=91&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=121&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=151&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=181&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=211&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=241&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=271&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=301&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=331&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=361&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=391&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=421&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=451&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=481&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=511&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=541&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=571&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=601&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=631&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=661&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=691&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=721&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=751&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=781&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=811&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=841&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=871&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=901&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=931&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=麻生太郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=あべ俊子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=あべ俊子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=あべ俊子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=91&speaker=あべ俊子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=あべ俊子&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=甘利明&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=甘利明&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=五十嵐清&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=五十嵐清&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=池田佳隆&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=池田佳隆&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=
speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2131&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2161&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2191&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2221&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2251&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2281&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2311&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2341&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2371&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2401&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2431&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2461&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=2491&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=加藤勝信&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=加藤竜祥&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=加藤竜祥&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=門山宏哲&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=門山宏哲&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=金子俊平&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=金子俊平&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=金子恭之&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=金子恭之&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=金子恭之&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=金子恭之&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=金田勝年&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=金田勝年&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=金田勝年&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=91&speaker=金田勝年&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=金田勝年&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=上川陽子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=上川陽子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=上川陽子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=91&speaker=上川陽子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=121&speaker=上川陽子&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=上川陽子&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=亀岡偉民&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=亀岡偉民&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=亀岡偉民&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=川崎ひでと&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=川崎ひでと&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=菅家一郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=菅家一郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=神田憲次&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=神田憲次&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=神田憲次&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=神田潤一&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=神田潤一&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=城内実&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=城内実&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=黄川田仁志&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=黄川田仁志&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=岸信千世&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=岸信千世&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=岸田文雄&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=岸田文雄&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=木原誠二&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=木原誠二&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=木原誠二&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=91&speaker=木原誠二&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=121&speaker=木原誠二&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=木原誠二&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=木原稔&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=木原稔&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=木村次郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=木村次郎&from=2020-01-01&until=2020-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=工藤彰三&from=2020-01-01&until=2020-12-31&recordPacking=json
# ...
# https://kokkai.ndl.go.jp/api/speech?startRecord=151&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=181&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=211&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=241&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=271&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=301&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=331&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=361&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=391&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=421&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=451&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=481&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=511&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=541&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=571&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=601&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=631&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=坂本哲志&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=櫻田義孝&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=櫻田義孝&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=笹川博義&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=笹川博義&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=笹川博義&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=笹川博義&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=佐々木紀&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=佐々木紀&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=佐藤勉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=佐藤勉&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=塩崎彰久&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=塩崎彰久&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=塩谷立&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=塩谷立&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=柴山昌彦&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=柴山昌彦&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=島尻安伊子&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=島尻安伊子&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=下村博文&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=下村博文&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=新谷正義&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=新谷正義&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=新谷正義&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=新藤義孝&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=None&speaker=新藤義孝&from=2021-01-01&until=2021-12-31&recordPacking=json
# No more records
# https://kokkai.ndl.go.jp/api/speech?startRecord=1&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=31&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=61&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=91&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=121&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=151&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=181&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=211&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=241&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=271&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=301&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=331&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# https://kokkai.ndl.go.jp/api/speech?startRecord=361&speaker=菅義偉&from=2021-01-01&until=2021-12-31&recordPacking=json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> 		name = member['name']
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> 		name = clean_repr_name(name)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> 		freq = get_speech_freq_for_repr_for_year(name, year)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> 		year_dict[f'{party} {name}'] = freq
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> output_arr.append(year_dict)
#
# /root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> def get_speech_freq_for_repr_for_year(repr_name, start_year):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> 	conditions_list = [
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> 			f"speaker={repr_name}",
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> 			f"from={start_year}-01-01",
#    (...)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> 			'recordPacking=json'
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> 	]
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> 	search_requests = mcc.make_requests(conditions_list=conditions_list)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/root/projects/kokkai_analysis/data_prepping/get_repr_speech_freq.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> 	return get_total_speech_freq_from_api(search_requests)
#
# File ~/projects/kokkai_analysis/data_prepping/api_requests/meeting_convo_collector.py:21, in MeetingConvoCollector.make_requests(self, conditions_list, max_length)
#      18 request_url = self.base_url+f"startRecord={starting_point}&"+conditions_link
#      19 print(request_url)
# ---> 21 response = requests.get(request_url)
#      22 response = response.json()
#      24 if "nextRecordPosition" not in response.keys():
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File ~/projects/kokkai_analysis/data_prepping/kokkai_venv/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:
